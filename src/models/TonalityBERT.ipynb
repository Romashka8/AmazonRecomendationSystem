# %%
import warnings

warnings.filterwarnings('ignore')

import tqdm
import os

import numpy as np
import pandas as pd

import torch
import transformers as ppb

# %% [markdown]
# # Подготовим и посмотрим данные

# %%
class TonalityDataset(torch.utils.data.Dataset):
  def __init__(self, path: str):
    self.data = pd.read_csv(path, delimiter='\t', header=None)

    self.max_sentence_len = 0
    for i in range(self.data.shape[0]):
      self.max_sentence_len = max(self.max_sentence_len, len(self.data.iloc[i][0]))

  def __len__(self):
    return self.data.shape[0]

  def __getitem__(self, index: int):
    return self.data.iloc[index][0]

# %%
# в репозитории архив находится тут: https://github.com/Romashka8/AmazonRecomendationSystem/tree/main/data/raw/tonality
# загрузим его с другого github-а - https://github.com/clairett/pytorch-sentiment-classification/raw/master/data/SST2/train.tsv
df = TonalityDataset('https://github.com/clairett/pytorch-sentiment-classification/raw/master/data/SST2/train.tsv')

# %%
df.data.head()
# Out:
#                                                    0  1
# 0  a stirring , funny and finally transporting re...  1
# 1  apparently reassembled from the cutting room f...  0
# 2  they presume their audience wo n't sit still f...  0
# 3  this is a visually stunning rumination on love...  1
# 4  jonathan parker 's bartleby should have been t...  1

# %%
df.data.shape
# Out:
# (6920, 2)

# %%
df.data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6920 entries, 0 to 6919
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6920 non-null   object
#  1   1       6920 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 1.1 MB

# %% [markdown]
# # Подготовим Эмбединги

# %%
# Выберем, на каком процессоре будем учить модель
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
# Разобьем выборку на батчи
loader = torch.utils.data.DataLoader(df, batch_size=40)

# %%
# Загрузим distil-bert и его токенайзер
model_name = 'distilbert-base-uncased'
tokenizer = ppb.AutoTokenizer.from_pretrained(model_name)
bert_model = ppb.AutoModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %%
os.path.exists('/content/drive/MyDrive/colab_data')

if not os.path.exists('/content/drive/MyDrive/colab_data/TonalityBERTStates'):
  os.mkdir('/content/drive/MyDrive/colab_data/TonalityBERTStates')

# %%
save_path = '/content/drive/MyDrive/colab_data/TonalityBERTStates'
start_from_epoch = 0
end_on_epoch = 174
epoch = start_from_epoch

# Прогоняем данные через модель
loop = tqdm.tqdm(loader, leave=False)

for batch in loop:

    if start_from_epoch <= epoch < end_on_epoch:

      # Токенизация батча
      inputs = tokenizer(batch, padding='max_length',
                        max_length=df.max_sentence_len, return_tensors='pt')

      # Передача данных в модель
      with torch.no_grad():
          outputs = bert_model(**inputs)

      # Извлечение эмбеддингов последнего скрытого слоя
      last_hidden_states = outputs.last_hidden_state

      # Сохраним эмбединг
      pd.DataFrame(last_hidden_states[:, 0, :]).to_csv(
          os.path.join(save_path, f'state_epoch_{epoch}.csv')
      )

      epoch += 1

    else:
      print('All bathes embeded!')
      break

# %% [markdown]
# # Сохраним файлы

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/colab_data
# Out:
# /content/drive/MyDrive/colab_data

# %%
! zip -r TonalityBERTStates.zip TonalityBERTStates/
# Out:
#   adding: TonalityBERTStates/ (stored 0%)
#   adding: TonalityBERTStates/state_epoch_0.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_1.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_2.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_3.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_4.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_5.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_6.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_7.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_8.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_9.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_10.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_11.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_12.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_13.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_14.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_15.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_16.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_17.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_18.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_19.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_20.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_21.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_22.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_23.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_24.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_25.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_26.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_27.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_28.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_29.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_30.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_31.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_32.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_33.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_34.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_35.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_36.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_37.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_38.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_39.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_40.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_41.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_42.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_43.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_44.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_45.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_46.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_47.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_48.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_49.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_50.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_51.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_52.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_53.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_54.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_55.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_56.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_57.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_58.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_59.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_60.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_61.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_62.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_63.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_64.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_65.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_66.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_67.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_68.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_69.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_70.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_71.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_72.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_73.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_74.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_75.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_76.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_77.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_78.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_79.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_80.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_81.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_82.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_83.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_84.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_85.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_86.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_87.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_88.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_89.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_90.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_91.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_92.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_93.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_94.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_95.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_96.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_97.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_98.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_99.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_100.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_101.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_102.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_103.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_104.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_105.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_106.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_107.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_108.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_109.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_110.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_111.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_112.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_113.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_114.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_115.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_116.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_117.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_118.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_119.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_120.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_121.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_122.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_123.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_124.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_125.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_126.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_127.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_128.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_129.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_130.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_131.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_132.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_133.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_134.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_135.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_136.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_137.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_138.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_139.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_140.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_141.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_142.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_143.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_144.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_145.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_146.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_147.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_148.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_149.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_150.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_151.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_152.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_153.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_154.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_155.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_156.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_157.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_158.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_159.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_160.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_161.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_162.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_163.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_164.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_165.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_166.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_167.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_168.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_169.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_170.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_171.csv (deflated 58%)
#   adding: TonalityBERTStates/state_epoch_172.csv (deflated 58%)

# %%
from google.colab import files
files.download('TonalityBERTStates.zip')
