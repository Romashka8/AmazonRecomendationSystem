# %%
import warnings

warnings.filterwarnings('ignore')

import tqdm
import pickle
import os

import numpy as np
import pandas as pd

import torch
import transformers as ppb

# %% [markdown]
# # Подготовим и посмотрим данные

# %%
class TonalityDataset(torch.utils.data.Dataset):
  def __init__(self, path: str):
    self.data = pd.read_csv(path, delimiter='\t', header=None)

    self.max_sentence_len = 0
    for i in range(self.data.shape[0]):
      self.max_sentence_len = max(self.max_sentence_len, len(self.data.iloc[i][0]))

  def __len__(self):
    return self.data.shape[0]

  def __getitem__(self, index: int):
    return self.data.iloc[index][0]

# %%
# в репозитории архив находится тут: https://github.com/Romashka8/AmazonRecomendationSystem/tree/main/data/raw/tonality
# загрузим его с другого github-а - https://github.com/clairett/pytorch-sentiment-classification/raw/master/data/SST2/train.tsv
df = TonalityDataset('https://github.com/clairett/pytorch-sentiment-classification/raw/master/data/SST2/train.tsv')

# %%
df.data.head()
# Out:
#                                                    0  1
# 0  a stirring , funny and finally transporting re...  1
# 1  apparently reassembled from the cutting room f...  0
# 2  they presume their audience wo n't sit still f...  0
# 3  this is a visually stunning rumination on love...  1
# 4  jonathan parker 's bartleby should have been t...  1

# %%
df.data.shape
# Out:
# (6920, 2)

# %%
df.data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6920 entries, 0 to 6919
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6920 non-null   object
#  1   1       6920 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 1.1 MB

# %% [markdown]
# # Подготовим Эмбединги

# %%
# Выберем, на каком процессоре будем учить модель
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
# Разобьем выборку на батчи
loader = torch.utils.data.DataLoader(df, batch_size=40)

# %%
# Загрузим distil-bert и его токенайзер
model_name = 'distilbert-base-uncased'
tokenizer = ppb.AutoTokenizer.from_pretrained(model_name)
bert_model = ppb.AutoModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %%
os.path.exists('/content/drive/MyDrive/colab_data')

if not os.path.exists('/content/drive/MyDrive/colab_data/TonalityBERTStates'):
  os.mkdir('/content/drive/MyDrive/colab_data/TonalityBERTStates')

# %%
save_every_iter = 1
save_path = '/content/drive/MyDrive/colab_data/TonalityBERTStates'
start_from_epoch = 0
end_on_epoch = 174
epoch = start_from_epoch

# Прогоняем данные через модель
loop = tqdm.tqdm(loader, leave=False)

for batch in loop:

    if start_from_epoch <= epoch < end_on_epoch:

      # Токенизация батча
      inputs = tokenizer(batch, padding='max_length',
                        max_length=df.max_sentence_len, return_tensors='pt')

      # Передача данных в модель
      with torch.no_grad():
          outputs = bert_model(**inputs)

      # Извлечение эмбеддингов последнего скрытого слоя
      last_hidden_states = outputs.last_hidden_state

      # Сохраним эмбединг
      if epoch % save_every_iter == 0:
        with open(os.path.join(save_path, f'state_epoch_{epoch}.pkl'), 'wb') as f:
          pickle.dump([last_hidden_states[:, 0, :],
                      epoch, start_from_epoch, end_on_epoch], f)

      epoch += 1

    else:
      print('All bathes embeded!')
      break

# %% [markdown]
# # Сохраним файлы

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/colab_data
# Out:
# /content/drive/MyDrive/colab_data

# %%
! zip -r TonalityBERTStates.zip TonalityBERTStates/
# Out:
#   adding: TonalityBERTStates/ (stored 0%)
#   adding: TonalityBERTStates/state_epoch_0.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_1.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_2.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_3.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_4.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_5.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_6.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_7.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_8.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_9.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_10.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_11.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_12.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_13.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_14.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_15.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_16.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_17.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_18.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_19.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_20.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_21.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_22.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_23.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_24.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_25.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_26.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_27.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_28.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_29.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_30.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_31.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_32.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_33.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_34.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_35.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_36.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_37.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_38.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_39.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_40.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_41.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_42.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_43.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_44.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_45.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_46.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_47.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_48.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_49.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_50.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_51.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_52.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_53.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_54.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_55.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_56.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_57.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_58.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_59.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_60.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_61.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_62.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_63.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_64.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_65.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_66.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_67.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_68.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_69.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_70.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_71.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_72.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_73.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_74.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_75.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_76.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_77.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_78.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_79.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_80.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_81.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_82.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_83.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_84.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_85.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_86.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_87.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_88.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_89.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_90.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_91.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_92.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_93.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_94.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_95.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_96.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_97.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_98.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_99.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_100.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_101.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_102.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_103.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_104.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_105.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_106.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_107.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_108.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_109.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_110.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_111.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_112.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_113.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_114.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_115.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_116.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_117.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_118.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_119.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_120.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_121.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_122.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_123.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_124.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_125.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_126.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_127.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_128.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_129.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_130.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_131.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_132.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_133.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_134.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_135.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_136.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_137.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_138.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_139.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_140.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_141.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_142.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_143.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_144.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_145.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_146.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_147.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_148.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_149.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_150.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_151.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_152.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_153.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_154.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_155.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_156.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_157.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_158.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_159.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_160.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_161.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_162.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_163.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_164.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_165.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_166.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_167.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_168.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_169.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_170.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_171.pkl (deflated 7%)
#   adding: TonalityBERTStates/state_epoch_172.pkl (deflated 7%)

# %%
from google.colab import files
files.download('TonalityBERTStates.zip')
